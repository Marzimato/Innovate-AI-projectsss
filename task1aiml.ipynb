# %%
import numpy as np


matrix = np.random.randint(1,5, size=(5,4))
matrix
# Out:
# array([[2, 1, 4, 2],
#        [2, 3, 1, 3],
#        [2, 4, 2, 2],
#        [2, 4, 2, 2],
#        [2, 1, 3, 4]], dtype=int32)

# %%
transposed_matrix = matrix.T
transposed_matrix
# Out:
# array([[2, 2, 2, 2, 2],
#        [1, 3, 4, 4, 1],
#        [4, 1, 2, 2, 3],
#        [2, 3, 2, 2, 4]], dtype=int32)

# %%
column_mean = np.mean(matrix, axis=0 )
row_std_deviation = np.std(matrix, axis=1)
column_mean
# Out:
# array([2. , 2.6, 2.4, 2.6])

# %%
row_std_deviation
# Out:
# array([1.08972474, 0.8291562 , 0.8660254 , 0.8660254 , 1.11803399])

# %%
dot_prod = np.dot(matrix, transposed_matrix)
dot_prod
# Out:
# array([[25, 17, 20, 20, 25],
#        [17, 23, 24, 24, 22],
#        [20, 24, 28, 28, 22],
#        [20, 24, 28, 28, 22],
#        [25, 22, 22, 22, 30]], dtype=int32)
